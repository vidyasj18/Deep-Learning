# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
print(df.shape)
df.head()
# Out:
# (100, 3)
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(data=df, x='cgpa', y='resume_score', hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.linear_model import Perceptron
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
# w1,w2 values
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
# b - value
p.intercept_
# Out:
# array([-25.])

# %%
# !pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting scipy>=1.16.3 (from mlxtend)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting numpy>=2.3.5 (from mlxtend)
#   Downloading numpy-2.4.6-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.3 (from mlxtend)
#   Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting scikit-learn>=1.8.0 (from mlxtend)
#   Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting joblib>=1.5.2 (from mlxtend)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=9 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\vidya\appdata\roaming\python\python313\site-packages (from pandas>=2.3.3->mlxtend) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Collecting narwhals>=2.0.1 (from scikit-learn>=1.8.0->mlxtend)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ----------------------- ---------------- 0.8/1.4 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 2.3 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.3 MB 4.1 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.3 MB 4.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/9.3 MB 4.3 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.3 MB 4.6 MB/s eta 0:00:02
#    --------------------- ------------------ 5.0/9.3 MB 4.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.8/9.3 MB 4.8 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.3 MB 4.8 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.3 MB 4.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.8/9.3 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 4.0 MB/s  0:00:02
# Downloading numpy-2.4.6-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.3 MB 6.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/12.3 MB 4.1 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.3 MB 4.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.3 MB 4.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.3 MB 4.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.0/12.3 MB 4.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.3 MB 3.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.2/12.3 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.3 MB 3.3 MB/s eta 0:00:02
#    ------------------- -------------------- 6.0/12.3 MB 3.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 6.8/12.3 MB 3.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.3 MB 2.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.3 MB 2.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.3 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.3 MB 2.5 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.3 MB 2.5 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.3 MB 2.3 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.3 MB 2.3 MB/s eta 0:00:02
#    -------------------------- ------------- 8.1/12.3 MB 2.0 MB/s eta 0:00:03
#    --------------------------- ------------ 8.4/12.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 2.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.4/12.3 MB 2.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.7/12.3 MB 1.7 MB/s eta 0:00:03
#    ------------------------------- -------- 9.7/12.3 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 1.8 MB/s eta 0:00:02
#    --------------------------------- ------ 10.2/12.3 MB 1.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 10.7/12.3 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 1.9 MB/s  0:00:06
# Downloading pandas-3.0.3-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.8 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.8 MB 2.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.8 MB 2.4 MB/s eta 0:00:03
#    ------------- -------------------------- 3.4/9.8 MB 2.4 MB/s eta 0:00:03
#    --------------- ------------------------ 3.7/9.8 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.8 MB 2.5 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/9.8 MB 2.8 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.8 MB 2.9 MB/s eta 0:00:02
#    ------------------------------ --------- 7.3/9.8 MB 3.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.8 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 3.4 MB/s  0:00:02
# Downloading scikit_learn-1.9.0-cp313-cp313-win_amd64.whl (8.2 MB)
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.2 MB 2.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.2 MB 2.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.2 MB 3.3 MB/s eta 0:00:02
#    -------------- ------------------------- 2.9/8.2 MB 3.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.7/8.2 MB 3.6 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.2 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.2 MB 4.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.2 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 4.5 MB/s  0:00:01
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.5 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.5 MB 4.7 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/36.5 MB 2.3 MB/s eta 0:00:16
#    -- ------------------------------------- 2.6/36.5 MB 3.5 MB/s eta 0:00:10
#    --- ------------------------------------ 2.9/36.5 MB 3.6 MB/s eta 0:00:10
#    --- ------------------------------------ 3.4/36.5 MB 2.8 MB/s eta 0:00:12
#    --- ------------------------------------ 3.4/36.5 MB 2.8 MB/s eta 0:00:12
#    ---- ----------------------------------- 3.9/36.5 MB 2.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 3.9/36.5 MB 2.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 5.0/36.5 MB 2.4 MB/s eta 0:00:13
#    ------ --------------------------------- 6.3/36.5 MB 2.8 MB/s eta 0:00:11
#    ------- -------------------------------- 6.6/36.5 MB 2.8 MB/s eta 0:00:11
#    ------- -------------------------------- 7.1/36.5 MB 2.6 MB/s eta 0:00:12
#    -------- ------------------------------- 8.1/36.5 MB 2.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 9.4/36.5 MB 3.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.7/36.5 MB 3.2 MB/s eta 0:00:08
#    ------------- -------------------------- 12.1/36.5 MB 3.4 MB/s eta 0:00:08
#    ------------- -------------------------- 12.6/36.5 MB 3.5 MB/s eta 0:00:07
#    -------------- ------------------------- 13.1/36.5 MB 3.4 MB/s eta 0:00:07
#    --------------- ------------------------ 13.9/36.5 MB 3.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 14.7/36.5 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.0/36.5 MB 3.5 MB/s eta 0:00:06
#    ------------------ --------------------- 17.3/36.5 MB 3.6 MB/s eta 0:00:06
#    ------------------- -------------------- 18.1/36.5 MB 3.6 MB/s eta 0:00:06
#    -------------------- ------------------- 19.1/36.5 MB 3.7 MB/s eta 0:00:05
#    ---------------------- ----------------- 20.4/36.5 MB 3.8 MB/s eta 0:00:05
#    ----------------------- ---------------- 21.8/36.5 MB 3.9 MB/s eta 0:00:04
#    ------------------------- -------------- 23.1/36.5 MB 4.0 MB/s eta 0:00:04
#    -------------------------- ------------- 24.4/36.5 MB 4.0 MB/s eta 0:00:04
#    --------------------------- ------------ 25.4/36.5 MB 4.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 26.0/36.5 MB 4.0 MB/s eta 0:00:03
#    ---------------------------- ----------- 26.2/36.5 MB 4.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.3/36.5 MB 4.0 MB/s eta 0:00:03
#    ------------------------------ --------- 28.0/36.5 MB 4.0 MB/s eta 0:00:03
#    ------------------------------- -------- 29.1/36.5 MB 4.0 MB/s eta 0:00:02
#    --------------------------------- ------ 30.1/36.5 MB 4.0 MB/s eta 0:00:02
#    --------------------------------- ------ 30.4/36.5 MB 4.0 MB/s eta 0:00:02
#    --------------------------------- ------ 30.9/36.5 MB 3.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 31.7/36.5 MB 3.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.0/36.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.5/36.5 MB 3.8 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.8/36.5 MB 3.8 MB/s eta 0:00:01
#    ------------------------------------ --- 33.3/36.5 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------ --- 33.3/36.5 MB 3.7 MB/s eta 0:00:01
#    ------------------------------------- -- 33.8/36.5 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 33.8/36.5 MB 3.6 MB/s eta 0:00:01
#    ------------------------------------- -- 34.3/36.5 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 34.3/36.5 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 34.6/36.5 MB 3.4 MB/s eta 0:00:01
#    -------------------------------------- - 34.9/36.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 35.1/36.5 MB 3.3 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.5 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 3.2 MB/s  0:00:14
# Installing collected packages: numpy, narwhals, joblib, scipy, pandas, scikit-learn, matplotlib, mlxtend
#
#   Attempting uninstall: numpy
#
#     Found existing installation: numpy 2.1.2
#
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#     Uninstalling numpy-2.1.2:
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#       Successfully uninstalled numpy-2.1.2
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#    ---------------------------------------- 0/8 [numpy]
#   Attempting uninstall: narwhals
#    ---------------------------------------- 0/8 [numpy]
#     Found existing installation: narwhals 1.41.0
#    ---------------------------------------- 0/8 [numpy]
#    ----- ---------------------------------- 1/8 [narwhals]
#     Uninstalling narwhals-1.41.0:
#    ----- ---------------------------------- 1/8 [narwhals]
#       Successfully uninstalled narwhals-1.41.0
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#    ----- ---------------------------------- 1/8 [narwhals]
#   Attempting uninstall: joblib
#    ----- ---------------------------------- 1/8 [narwhals]
#     Found existing installation: joblib 1.5.1
#    ----- ---------------------------------- 1/8 [narwhals]
#     Uninstalling joblib-1.5.1:
#    ----- ---------------------------------- 1/8 [narwhals]
#       Successfully uninstalled joblib-1.5.1
#    ----- ---------------------------------- 1/8 [narwhals]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#    ---------- ----------------------------- 2/8 [joblib]
#   Attempting uninstall: scipy
#    ---------- ----------------------------- 2/8 [joblib]
#     Found existing installation: scipy 1.15.3
#    ---------- ----------------------------- 2/8 [joblib]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#     Uninstalling scipy-1.15.3:
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#       Successfully uninstalled scipy-1.15.3
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#    --------------- ------------------------ 3/8 [scipy]
#   Attempting uninstall: pandas
#    --------------- ------------------------ 3/8 [scipy]
#     Found existing installation: pandas 2.2.3
#    --------------- ------------------------ 3/8 [scipy]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#     Uninstalling pandas-2.2.3:
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#       Successfully uninstalled pandas-2.2.3
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
# ...
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#    -------------------- ------------------- 4/8 [pandas]
#   Attempting uninstall: scikit-learn
#    -------------------- ------------------- 4/8 [pandas]
#     Found existing installation: scikit-learn 1.6.1
#    -------------------- ------------------- 4/8 [pandas]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#     Uninstalling scikit-learn-1.6.1:
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.6.1
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------- -------------- 5/8 [scikit-learn]
#   Attempting uninstall: matplotlib
#    ------------------------- -------------- 5/8 [scikit-learn]
#     Found existing installation: matplotlib 3.10.6
#    ------------------------- -------------- 5/8 [scikit-learn]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#     Uninstalling matplotlib-3.10.6:
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~umpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~cipy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~cipy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~andas.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~andas'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~klearn'.
#   You can safely remove it manually.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\vidya\\appdata\\roaming\\python\\python313\\site-packages\\matplotlib\\backends\\_backend_agg.cp313-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys

# %%
print(sys.executable)
# Out:
# C:\Python313\python.exe

# %%
# %pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Using cached mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from mlxtend) (2.4.6)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from mlxtend) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from mlxtend) (1.9.0)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Using cached matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=9 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\vidya\appdata\roaming\python\python313\site-packages (from pandas>=2.3.3->mlxtend) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\vidya\appdata\roaming\python\python313\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Using cached mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
# Using cached matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
# Installing collected packages: matplotlib, mlxtend
#
#    ---------------------------------------- 0/2 [matplotlib]
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\VIDYA\\AppData\\Roaming\\Python\\Python313\\site-packages\\matplotlib\\backends\\_backend_agg.cp313-win_amd64.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip --version
# Out:
# pip 25.3 from C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\pip (python 3.13)

# %%
import sys
print(sys.executable)
# Out:
# C:\Python313\python.exe

# %%
# !pip --version
# Out:
# pip 25.3 from C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\pip (python 3.13)

# %%
# !pip show mlxtend
# Out:
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Package(s) not found: mlxtend

# %%
import sys
# !{sys.executable} -m pip uninstall matplotlib -y
# !{sys.executable} -m pip install --upgrade --force-reinstall matplotlib
# Out:
# Found existing installation: matplotlib 3.11.0
# error: uninstall-no-record-file
#
# Cannot uninstall matplotlib 3.11.0
#
# The package's contents are unknown: no RECORD file was found for matplotlib.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps matplotlib==3.11.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting matplotlib
#   Using cached matplotlib-3.11.0-cp313-cp313-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# Collecting numpy>=1.25 (from matplotlib)
#   Using cached numpy-2.4.6-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting packaging>=20.0 (from matplotlib)
#   Downloading packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached matplotlib-3.11.0-cp313-cp313-win_amd64.whl (9.3 MB)
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.1 MB/s eta 0:00:02
#    -------------------------- ------------- 1.6/2.3 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.7 MB/s  0:00:01
# Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# Using cached numpy-2.4.6-cp313-cp313-win_amd64.whl (12.3 MB)
# Downloading packaging-26.2-py3-none-any.whl (100 kB)
# Downloading pillow-12.2.0-cp313-cp313-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.1 MB 3.7 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.1 MB 3.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/7.1 MB 3.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.1 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.1 MB 3.6 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 4.4 MB/s  0:00:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, cycler, python-dateutil, contourpy, matplotlib
#
#   Attempting uninstall: six
#
#     Found existing installation: six 1.17.0
#
#     Uninstalling six-1.17.0:
#
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#    ----------------------------------------  0/11 [six]
#       Successfully uninstalled six-1.17.0
#    ----------------------------------------  0/11 [six]
#   Attempting uninstall: pyparsing
#    ----------------------------------------  0/11 [six]
#    --- ------------------------------------  1/11 [pyparsing]
#     Found existing installation: pyparsing 3.2.5
#    --- ------------------------------------  1/11 [pyparsing]
#     Uninstalling pyparsing-3.2.5:
#    --- ------------------------------------  1/11 [pyparsing]
#       Successfully uninstalled pyparsing-3.2.5
#    --- ------------------------------------  1/11 [pyparsing]
#    --- ------------------------------------  1/11 [pyparsing]
#    --- ------------------------------------  1/11 [pyparsing]
#    --- ------------------------------------  1/11 [pyparsing]
#    --- ------------------------------------  1/11 [pyparsing]
#   Attempting uninstall: pillow
#    --- ------------------------------------  1/11 [pyparsing]
#     Found existing installation: pillow 11.2.1
#    --- ------------------------------------  1/11 [pyparsing]
#     Uninstalling pillow-11.2.1:
#    --- ------------------------------------  1/11 [pyparsing]
#       Successfully uninstalled pillow-11.2.1
#    --- ------------------------------------  1/11 [pyparsing]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#    ------- --------------------------------  2/11 [pillow]
#   Attempting uninstall: packaging
#    ------- --------------------------------  2/11 [pillow]
#     Found existing installation: packaging 24.2
#    ------- --------------------------------  2/11 [pillow]
#     Uninstalling packaging-24.2:
#    ------- --------------------------------  2/11 [pillow]
#       Successfully uninstalled packaging-24.2
#    ------- --------------------------------  2/11 [pillow]
#    ---------- -----------------------------  3/11 [packaging]
#    ---------- -----------------------------  3/11 [packaging]
#    ---------- -----------------------------  3/11 [packaging]
#    ---------- -----------------------------  3/11 [packaging]
#    ---------- -----------------------------  3/11 [packaging]
#   Attempting uninstall: numpy
#    ---------- -----------------------------  3/11 [packaging]
#     Found existing installation: numpy 2.4.6
#    ---------- -----------------------------  3/11 [packaging]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#     Uninstalling numpy-2.4.6:
#    -------------- -------------------------  4/11 [numpy]
#       Successfully uninstalled numpy-2.4.6
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#    -------------- -------------------------  4/11 [numpy]
#   Attempting uninstall: kiwisolver
#    -------------- -------------------------  4/11 [numpy]
#     Found existing installation: kiwisolver 1.4.9
#    -------------- -------------------------  4/11 [numpy]
#     Uninstalling kiwisolver-1.4.9:
#    -------------- -------------------------  4/11 [numpy]
#       Successfully uninstalled kiwisolver-1.4.9
#    -------------- -------------------------  4/11 [numpy]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#    ------------------ ---------------------  5/11 [kiwisolver]
#   Attempting uninstall: fonttools
#    ------------------ ---------------------  5/11 [kiwisolver]
#     Found existing installation: fonttools 4.60.0
#    ------------------ ---------------------  5/11 [kiwisolver]
#    --------------------- ------------------  6/11 [fonttools]
#     Uninstalling fonttools-4.60.0:
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#       Successfully uninstalled fonttools-4.60.0
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#    --------------------- ------------------  6/11 [fonttools]
#   Attempting uninstall: cycler
#    --------------------- ------------------  6/11 [fonttools]
#     Found existing installation: cycler 0.12.1
#    --------------------- ------------------  6/11 [fonttools]
#     Uninstalling cycler-0.12.1:
#    --------------------- ------------------  6/11 [fonttools]
#       Successfully uninstalled cycler-0.12.1
#    --------------------- ------------------  6/11 [fonttools]
#   Attempting uninstall: python-dateutil
#    --------------------- ------------------  6/11 [fonttools]
#     Found existing installation: python-dateutil 2.9.0.post0
#    --------------------- ------------------  6/11 [fonttools]
#    ----------------------------- ----------  8/11 [python-dateutil]
#     Uninstalling python-dateutil-2.9.0.post0:
#    ----------------------------- ----------  8/11 [python-dateutil]
#       Successfully uninstalled python-dateutil-2.9.0.post0
#    ----------------------------- ----------  8/11 [python-dateutil]
#    ----------------------------- ----------  8/11 [python-dateutil]
#    ----------------------------- ----------  8/11 [python-dateutil]
#    ----------------------------- ----------  8/11 [python-dateutil]
#   Attempting uninstall: contourpy
#    ----------------------------- ----------  8/11 [python-dateutil]
#     Found existing installation: contourpy 1.3.3
#    ----------------------------- ----------  8/11 [python-dateutil]
#    -------------------------------- -------  9/11 [contourpy]
#     Uninstalling contourpy-1.3.3:
#    -------------------------------- -------  9/11 [contourpy]
#       Successfully uninstalled contourpy-1.3.3
#    -------------------------------- -------  9/11 [contourpy]
#    -------------------------------- -------  9/11 [contourpy]
#    -------------------------------- -------  9/11 [contourpy]
#    -------------------------------- -------  9/11 [contourpy]
#   Attempting uninstall: matplotlib
#    -------------------------------- -------  9/11 [contourpy]
#     Found existing installation: matplotlib 3.11.0
#    -------------------------------- -------  9/11 [contourpy]
#    ------------------------------------ --- 10/11 [matplotlib]
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~il'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\~iwisolver'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: uninstall-no-record-file
#
# Cannot uninstall matplotlib 3.11.0
#
# The package's contents are unknown: no RECORD file was found for matplotlib.
#
# hint: You might be able to recover from this via: pip install --force-reinstall --no-deps matplotlib==3.11.0

# %%
# Create a mesh grid
x_min, x_max = X.iloc[:, 0].min() - 1, X.iloc[:, 0].max() + 1
y_min, y_max = X.iloc[:, 1].min() - 1, X.iloc[:, 1].max() + 1

xx, yy = np.meshgrid(
    np.arange(x_min, x_max, 0.01),
    np.arange(y_min, y_max, 0.01)
)

# %%
# Predict on every point in the grid
Z = p.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
# Out:
# C:\Users\VIDYA\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   equal length arrays, then the output is a 2D numpy.array.

# %%
# Plot decision regions
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, alpha=0.3)

# %%
# Plot the original data points
scatter = plt.scatter(
    X.iloc[:, 0],
    X.iloc[:, 1],
    c=y,
    edgecolor='k'
)

plt.xlabel(X.columns[0])
plt.ylabel(X.columns[1])
plt.title("Decision Boundary")
plt.legend(*scatter.legend_elements(), title="Classes")
plt.show()
